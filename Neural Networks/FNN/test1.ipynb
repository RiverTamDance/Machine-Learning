# %%
list(range(1))
# Out:
# [0]

# %%
if k in [*d.keys() for d in ds]:
    ...

chain(*[d.keys ])

# %%
max(0,1.1)
# Out:
# 1.1

# %%
def d_ReLU_branchless(x):
    a = max(0,x)
    b = x
    r = a and a/b or 0
    return(r)

d_ReLU_branchless(.5)
# Out:
# 1.0

# %%
0 and 0 or 1
#if 'or' was evaluated first, this would give 0 and 1 = 0
# however, now we know that and is evaluated first, giving 0 or 1 = 1
# Out:
# 1

# %%
0 and 1 or 0
# Out:
# 0
